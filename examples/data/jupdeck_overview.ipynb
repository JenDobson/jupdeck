# %% [markdown]
# # JupDeck: Turn Jupyter Notebooks into Presentation-Ready Slides
#
# - Automate the creation of PowerPoint slides from Jupyter notebooks
# - Save hours of copying, pasting, and formatting
# - Keep your data analysis and communication in sync

# %% [markdown]
# # How It Works
#
# 1. Parses your notebook’s structure and outputs
# 2. Matches content to slide layouts
# 3. Generates .pptx deck using python-pptx
#
# Customize with:
# - Command-line flags (e.g. `--no-speaker-notes`)
# - YAML configs (coming soon)
# - Your own PowerPoint templates (coming soon)

# %% [markdown]
# # Automatic Slide Breaks
#
# * New slides are automatically created from Level-1 (#) markdown headings
# * Bulleted text is rendered as bullets in presentation
# * Slide directives (e.g. "hide-content", "new-slide") coming soon
#
# Paragraph text is rendered as speaker notes.  (PowerPoint and Google Slides only)

# %% [markdown]
# # Plot Rendering
# * Code cell outputs are rendered as images to slides
# * Sometimes there are multiple plots in a section
# * The default layout puts the first plot in the lower left
# * All subsequent plots are overlayed lower right

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3], [4, 3, 5])
plt.title("First Plot")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3], [4, 3, 5])
plt.title("Second Plot")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3], [4, 3, 5])
plt.title("Third Plot")
plt.show()

# %% [markdown]
# # Tables Rendered as Slides
#
# Tabular output from pandas (or other libraries) is automatically converted into slide content.
# - Small tables are rendered directly
# - Large tables are truncated or linked

# %%
import pandas as pd

df = pd.DataFrame({
    "Dataset": ["A", "B", "C", "D"],
    "Rows": [1200, 3400, 230, 9800],
    "Source": ["internal", "public", "public", "internal"]
})

df
# Out:
#   Dataset  Rows    Source
# 0       A  1200  internal
# 1       B  3400    public
# 2       C   230    public
# 3       D  9800  internal

# %% [markdown]
# # Roadmap Highlights
#
# - Smart layout engine
# - Custom themes (corporate, dark mode)
# - LLM-powered summarization
# - See more at: https://github.com/JenDobson/jupdeck
