# %% [markdown]
# # 📘 Sample Analysis Notebook
# This notebook demonstrates a basic data analysis workflow using Python. We'll begin by exploring a sample dataset, visualizing the raw data, and performing a linear regression analysis to uncover trends.

# %% [markdown]
# ## 📚 Background
# Data analysis is a critical part of any decision-making process. In this notebook, we'll work with a simple synthetic dataset where the relationship between the variables is known. This allows us to validate our analysis techniques and visualize how linear regression can be used to model trends.

# %%
# 📊 Data Exploration
import matplotlib.pyplot as plt
import pandas as pd

data = pd.DataFrame({"x": range(10), "y": [2 * i + 1 for i in range(10)]})
data
# Out:
#    x   y
# 0  0   1
# 1  1   3
# 2  2   5
# 3  3   7
# 4  4   9
# 5  5  11
# 6  6  13
# 7  7  15
# 8  8  17
# 9  9  19

# %%
plt.figure(figsize=(6, 4))
plt.plot(data["x"], data["y"], marker="o")
plt.title("Raw Data Plot")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.show()

# %% [markdown]
# ## 🔍 Analysis
# To quantify the relationship between `x` and `y`, we'll use linear regression. This will allow us to model `y` as a function of `x` and determine the slope and intercept that best fit the data.

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(data[["x"]], data["y"])
predicted = model.predict(data[["x"]])
plt.figure(figsize=(6, 4))
plt.scatter(data["x"], data["y"], label="Data")
plt.plot(data["x"], predicted, color="red", label="Regression Line")
plt.title("Linear Regression")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()
model.coef_, model.intercept_
# Out:
# (array([2.]), np.float64(0.9999999999999982))

# %% [markdown]
# ## ✅ Summary and Conclusions
# In this notebook, we demonstrated a basic data analysis pipeline:
# - We created a synthetic dataset with a known linear relationship.
# - We visualized the raw data using line plots.
# - We applied linear regression to model the relationship between variables.
# The results confirm a clear linear trend with a slope of approximately 2 and an intercept of 1.
